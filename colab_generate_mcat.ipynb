# %% [markdown]
# # MCAT Question Generation (Colab)
#
# Minimal notebook to run the pipeline in Google Colab.
#
# 1. Install dependencies
# 2. (Optional) Mount Google Drive
# 3. Set API key
# 4. Run generation

# %%
# Install dependencies
# !pip install -q -r requirements.txt

# %%
# Optional: mount Google Drive to persist outputs
# from google.colab import drive
# drive.mount("/content/drive")
# Then copy data/output to a folder on Drive when done.

# %%
# Set your API key (use Colab Secrets or paste here)
import os
os.environ["OPENAI_API_KEY"] = "your-key-here"

# %%
# Ensure data dir exists and you have data/topics.json in the repo
# !mkdir -p data/output

# %%
# Run generation (science + CARS)
# !python run_generation.py --mode both
